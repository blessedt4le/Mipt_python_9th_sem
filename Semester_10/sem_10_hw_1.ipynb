# %%
import pandas as pd

# %%
df = pd.read_csv("Datasets/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df_male = df[df["Sex"] == "male"]
df_female = df[df["Sex"] == "female"]

# %%
df_wtht_nan = df.dropna(subset=["Embarked"])
df_wtht_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          712 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Cabin        202 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.3+ KB

# %%
df_wtht_nan["Age"].fillna(df["Age"].mean(), inplace=True)
# Out:
# C:\Users\looki\AppData\Local\Temp\ipykernel_9644\517250964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wtht_nan["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
df_wtht_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Cabin        202 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.3+ KB

# %%
mode_сabin = df['Cabin'].mode()
mode_сabin
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %%
mode_сabin[0]
# Out:
# 'B96 B98'

# %%
cabin_fill = mode_сabin[0].split()[0]
cabin_fill
# Out:
# 'B96'

# %%
df_wtht_nan["Cabin"].fillna(cabin_fill, inplace=True)
# Out:
# C:\Users\looki\AppData\Local\Temp\ipykernel_9644\483687205.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wtht_nan["Cabin"].fillna(cabin_fill, inplace=True)

# %%
df_wtht_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    object
#  5   Age          889 non-null    float64
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Cabin        889 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.3+ KB

# %%
df_wtht_nan.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586   29.653446    0.524184
# std     256.998173    0.486260    0.834700   12.968366    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.000000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.382452   32.096681
# std      0.806761   49.697504
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import matplotlib.pyplot as plt

# %%
age_hist = df_wtht_nan["Age"].hist(bins=10, edgecolor="black", grid=False)
plt.title("Распределение возраста")
plt.xlabel("Возраст")
plt.ylabel("Частота")
# Out:
# Text(0, 0.5, 'Частота')

# %%
plt.boxplot(df_wtht_nan["Age"], vert=False, patch_artist=True,
            boxprops=dict(facecolor="lightblue"))
plt.title("Boxplot возраста")
plt.xlabel("Возраст")
# Out:
# Text(0.5, 0, 'Возраст')

# %%
plt.violinplot(df_wtht_nan["Age"], vert=False, showmedians=True)
plt.title("Violinplot возраста")
plt.xlabel("Возраст")

# %%
plt.scatter(range(len(df_wtht_nan["Age"])), df_wtht_nan["Age"], color="blue", 
            alpha=0.5)
plt.title("Scatter plot возраста")
plt.xlabel("Частота")
plt.ylabel("Возраст")
# Out:
# Text(0, 0.5, 'Возраст')

# %%
age_bins = [20, 30, 40, 50, 60, 70, 80]
age_groups = pd.cut(df["Age"], bins=age_bins)
age_group_counts = age_groups.value_counts().sort_index()
age_group_counts.plot(kind="bar", color="orange", edgecolor="black")
plt.title("Bar plot возраста")
plt.xlabel("Возрастные группы")
plt.ylabel("Количество")
# Out:
# Text(0, 0.5, 'Количество')

# %%
age_group_counts.plot(kind="pie", autopct='%1.1f%%', startangle=90, colors=
                      ["lightblue", "lightgreen", "lightcoral", "lightskyblue", 
                       "lightpink"])
plt.title("Pie chart возрастных групп")
# Out:
# Text(0.5, 1.0, 'Pie chart возрастных групп')
